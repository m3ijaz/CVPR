# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-5, 5, 1)

def plot_graph(y,ylabel):
    plt.figure()
    plt.plot(x, y, "o--")
    plt.grid(True)
    plt.xlabel("X")
    plt.ylabel(ylabel)
    plt.show()

# %% [markdown]
# # STEP FUNCTION

# %%
y = list(map(lambda n: 1 if n > 0.5 else 0, x) )
plot_graph(y, "Step_Function(X)")

# %% [markdown]
# # SIGMOID FUNCTION

# %%
y = 1/ (1 + np.exp(-x))
plot_graph(y, "Sigmoid_Function(X)")

# %% [markdown]
# # TANH FUNCTION

# %%
y = (np.exp(2*x) - 1) / (np.exp(2*x) + 1)
plot_graph(y, "Tanh_Function(X)")

# %% [markdown]
# # RELU FUNCTION

# %%
y = list (map(lambda a : a if a >= 0 else 0,x))
plot_graph(y, "Relu_Function(X)")

# %% [markdown]
# # ELU

# %%
import numpy as np
import matplotlib.pyplot as plt

def elu(x, alpha = 0.1):
    return np.where(x > 0, x, alpha * (np.exp(x) - 1))

x = np.linspace(-10, 10, 30)
y = list(map(lambda a: elu(a), x))
plot_graph(y, "ELU_Function")

# %% [markdown]
# # PRELU

# %%
import numpy as np
import matplotlib.pyplot as plt

alpha = 0.1

y = list(map(lambda a: a if a >= 0 else 0,x))
plot_graph(y, "Prelu_Frunction")
